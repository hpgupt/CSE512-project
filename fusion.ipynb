# %%
import pandas as pd
songs_df = pd.read_pickle('/content/drive/MyDrive/MLProject/song-embeddings.pkl')
lyric_df = pd.read_pickle('/content/drive/MyDrive/MLProject/lyrics-embeddings-final.pkl')

# %%
import ast

# %%
lyric_df['ast_embd'] = songs_df['ast_embd']

# %%
df=lyric_df

# %%
df.iloc[0]['text_embd_1'].shape
# Out:
# (1, 1024)

# %%
df.iloc[0]['ast_embd'].shape
# Out:
# (1, 768)

# %%
from sklearn.preprocessing import MultiLabelBinarizer
import ast
# df['merged_labels'] = df['merged_labels'].apply(ast.literal_eval)
all_genres=['electronic', 'rock', 'funk&soul', 'pop', 'folk&country', 'hiphop', 'rhythm&blues', 'jazz']
all_moods = ['happy/celebration/party/dance', 'loss/sad/heartbreak/angst/protest', 'romantic/love/passion/devotion', 'motivating/inspirational/uplifting/confidence/nostalgia']
mlb = MultiLabelBinarizer(classes=all_genres + all_moods)
df['labels'] = list(mlb.fit_transform(df['merged_labels']))
labels = mlb.classes_

# %%
print (labels)
# Out:
# ['electronic' 'rock' 'funk&soul' 'pop' 'folk&country' 'hiphop'
#  'rhythm&blues' 'jazz' 'happy/celebration/party/dance'
#  'loss/sad/heartbreak/angst/protest' 'romantic/love/passion/devotion'
#  'motivating/inspirational/uplifting/confidence/nostalgia']

# %%
from sklearn.model_selection import train_test_split
import numpy as np

train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42)

# %%
from torch.utils.data import Dataset, DataLoader

class CustomDataset(Dataset):
    def __init__(self, dataframe):
        self.labels = list(dataframe['labels'])
        self.text_embeddings = list(dataframe['text_embd_1'])
        self.ast_embeddings = list(dataframe['ast_embd'])

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return {
            'text_embedding': torch.tensor(self.text_embeddings[idx], dtype=torch.float),
            'ast_embedding': torch.tensor(self.ast_embeddings[idx], dtype=torch.float),
            'labels': torch.tensor(self.labels[idx], dtype=torch.float)
        }

# Create datasets
train_dataset = CustomDataset(train_df)
val_dataset = CustomDataset(val_df)
test_dataset = CustomDataset(test_df)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16)
test_loader = DataLoader(test_dataset, batch_size=16)

# %%
import torch

# %%
from torch import nn

class CustomClassificationHead(nn.Module):
    def __init__(self, roberta_hidden_size, ast_hidden_size, num_labels):
        super(CustomClassificationHead, self).__init__()
        self.total_hidden_size = roberta_hidden_size + ast_hidden_size
        self.layernorm = nn.LayerNorm(self.total_hidden_size)
        self.dense = nn.Linear(self.total_hidden_size, self.total_hidden_size)
        self.dropout = nn.Dropout(0.1)
        self.out_proj = nn.Linear(self.total_hidden_size, num_labels)

    def forward(self, roberta_embedding, ast_embedding):
        combined_embedding = torch.cat((roberta_embedding, ast_embedding), dim=1)
        normed_embedding = self.layernorm(combined_embedding)
        x = self.dropout(normed_embedding)
        x = self.dense(x)
        x = torch.tanh(x)
        x = self.dropout(x)
        x = self.out_proj(x)
        return x

# %%
from torch.nn import BCEWithLogitsLoss
from transformers import AdamW
from sklearn.metrics import f1_score, precision_score, recall_score, hamming_loss

loss_fn = BCEWithLogitsLoss()
epochs=30

# %%
def exact_match_accuracy(true_labels, predictions):
    exact_match = np.all(true_labels == predictions, axis=1)
    ema_accuracy = np.mean(exact_match)
    genre_true, mood_true = true_labels[:, :8], true_labels[:, 8:]
    genre_pred, mood_pred = predictions[:, :8], predictions[:, 8:]
    exact_match_genre = np.all(genre_true == genre_pred, axis=1)
    exact_match_mood = np.all(mood_true == mood_pred, axis=1)
    exact_match_genres = np.mean(exact_match_genre)
    exact_match_moods = np.mean(exact_match_mood)
    return ema_accuracy, exact_match_genres, exact_match_moods

# %%
# Initialize the custom classification head
custom_head = CustomClassificationHead(1024, 768, len(mlb.classes_))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
custom_head.to(device)

# Loss function and optimizer
loss_fn = BCEWithLogitsLoss()
optimizer = AdamW(custom_head.parameters(), lr=6e-5)

for epoch in range(epochs):
    custom_head.train()
    total_train_loss = 0

    for batch in train_loader:
        optimizer.zero_grad()
        text_emb = batch['text_embedding'].to(device)
        ast_emb = batch['ast_embedding'].to(device)
        labels = batch['labels'].to(device)

        outputs = custom_head(text_emb.squeeze(1), ast_emb.squeeze(1))
        loss = loss_fn(outputs, labels)
        total_train_loss += loss.item()
        loss.backward()
        optimizer.step()

    avg_train_loss = total_train_loss / len(train_loader)
    print(f'Epoch {epoch+1} - Average Training Loss: {avg_train_loss:.4f}')

    # Validation loop
    custom_head.eval()
    total_val_loss = 0
    val_predictions = []
    val_true_labels = []

    with torch.no_grad():
        for batch in val_loader:
            text_emb = batch['text_embedding'].to(device)
            ast_emb = batch['ast_embedding'].to(device)
            labels = batch['labels'].to(device)

            outputs = custom_head(text_emb.squeeze(1), ast_emb.squeeze(1))
            loss = loss_fn(outputs, labels)
            total_val_loss += loss.item()

            val_predictions.append(torch.sigmoid(outputs).cpu().numpy())
            val_true_labels.append(labels.cpu().numpy())

    avg_val_loss = total_val_loss / len(val_loader)
    print(f'Epoch {epoch+1} - Average Validation Loss: {avg_val_loss:.4f}')

    # Calculate metrics
    val_predictions = np.vstack(val_predictions)
    val_true_labels = np.vstack(val_true_labels)
    threshold = 0.5
    val_predictions[val_predictions >= threshold] = 1
    val_predictions[val_predictions < threshold] = 0

    val_f1 = f1_score(val_true_labels, val_predictions, average='micro')
    val_precision = precision_score(val_true_labels, val_predictions, average='micro')
    val_recall = recall_score(val_true_labels, val_predictions, average='micro')
    val_hamming = hamming_loss(val_true_labels, val_predictions)
    ema_score, genre_score, mood_score = exact_match_accuracy(val_true_labels, val_predictions)

    print(f'Epoch {epoch+1} - Validation F1 Score: {val_f1:.4f}')
    print(f'Epoch {epoch+1} - Validation Precision: {val_precision:.4f}')
    print(f'Epoch {epoch+1} - Validation Recall: {val_recall:.4f}')
    print(f'Epoch {epoch+1} - Validation Hamming Loss: {val_hamming:.4f}')
    print(f"Exact Match Accuracy: {ema_score:.4f}")
    print(f"Exact genre Match Accuracy: {genre_score:.4f}")
    print(f"Exact mood Match Accuracy: {mood_score:.4f}")
    print ('-'*30)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch 1 - Average Training Loss: 0.2171
# Epoch 1 - Average Validation Loss: 0.2155
# Epoch 1 - Validation F1 Score: 0.7968
# Epoch 1 - Validation Precision: 0.8625
# Epoch 1 - Validation Recall: 0.7404
# Epoch 1 - Validation Hamming Loss: 0.0784
# Exact Match Accuracy: 0.4706
# Exact genre Match Accuracy: 0.5789
# Exact mood Match Accuracy: 0.8142
# ------------------------------
# Epoch 2 - Average Training Loss: 0.0931
# Epoch 2 - Average Validation Loss: 0.2130
# Epoch 2 - Validation F1 Score: 0.8127
# Epoch 2 - Validation Precision: 0.8697
# Epoch 2 - Validation Recall: 0.7627
# Epoch 2 - Validation Hamming Loss: 0.0730
# Exact Match Accuracy: 0.4954
# Exact genre Match Accuracy: 0.6006
# Exact mood Match Accuracy: 0.8204
# ------------------------------
# Epoch 3 - Average Training Loss: 0.0733
# Epoch 3 - Average Validation Loss: 0.2202
# Epoch 3 - Validation F1 Score: 0.8119
# Epoch 3 - Validation Precision: 0.8662
# Epoch 3 - Validation Recall: 0.7640
# Epoch 3 - Validation Hamming Loss: 0.0735
# Exact Match Accuracy: 0.4861
# Exact genre Match Accuracy: 0.5882
# Exact mood Match Accuracy: 0.8173
# ------------------------------
# Epoch 4 - Average Training Loss: 0.0639
# Epoch 4 - Average Validation Loss: 0.2247
# Epoch 4 - Validation F1 Score: 0.8182
# Epoch 4 - Validation Precision: 0.8603
# Epoch 4 - Validation Recall: 0.7801
# Epoch 4 - Validation Hamming Loss: 0.0720
# Exact Match Accuracy: 0.5077
# Exact genre Match Accuracy: 0.6130
# Exact mood Match Accuracy: 0.8142
# ------------------------------
# Epoch 5 - Average Training Loss: 0.0568
# Epoch 5 - Average Validation Loss: 0.2287
# Epoch 5 - Validation F1 Score: 0.8197
# Epoch 5 - Validation Precision: 0.8681
# Epoch 5 - Validation Recall: 0.7764
# Epoch 5 - Validation Hamming Loss: 0.0709
# Exact Match Accuracy: 0.5046
# Exact genre Match Accuracy: 0.6099
# Exact mood Match Accuracy: 0.8142
# ------------------------------
# Epoch 6 - Average Training Loss: 0.0528
# Epoch 6 - Average Validation Loss: 0.2279
# Epoch 6 - Validation F1 Score: 0.8213
# Epoch 6 - Validation Precision: 0.8610
# Epoch 6 - Validation Recall: 0.7851
# Epoch 6 - Validation Hamming Loss: 0.0709
# Exact Match Accuracy: 0.5294
# Exact genre Match Accuracy: 0.6316
# Exact mood Match Accuracy: 0.8204
# ------------------------------
# Epoch 7 - Average Training Loss: 0.0487
# Epoch 7 - Average Validation Loss: 0.2352
# Epoch 7 - Validation F1 Score: 0.8203
# Epoch 7 - Validation Precision: 0.8516
# Epoch 7 - Validation Recall: 0.7913
# Epoch 7 - Validation Hamming Loss: 0.0720
# Exact Match Accuracy: 0.5108
# Exact genre Match Accuracy: 0.6068
# Exact mood Match Accuracy: 0.8204
# ------------------------------
# Epoch 8 - Average Training Loss: 0.0452
# Epoch 8 - Average Validation Loss: 0.2330
# Epoch 8 - Validation F1 Score: 0.8189
# Epoch 8 - Validation Precision: 0.8443
# Epoch 8 - Validation Recall: 0.7950
# Epoch 8 - Validation Hamming Loss: 0.0730
# Exact Match Accuracy: 0.5263
# Exact genre Match Accuracy: 0.6223
# Exact mood Match Accuracy: 0.8173
# ------------------------------
# Epoch 9 - Average Training Loss: 0.0423
# Epoch 9 - Average Validation Loss: 0.2409
# Epoch 9 - Validation F1 Score: 0.8216
# Epoch 9 - Validation Precision: 0.8499
# Epoch 9 - Validation Recall: 0.7950
# Epoch 9 - Validation Hamming Loss: 0.0717
# Exact Match Accuracy: 0.5232
# Exact genre Match Accuracy: 0.6223
# Exact mood Match Accuracy: 0.8173
# ------------------------------
# Epoch 10 - Average Training Loss: 0.0400
# Epoch 10 - Average Validation Loss: 0.2412
# Epoch 10 - Validation F1 Score: 0.8269
# Epoch 10 - Validation Precision: 0.8543
# Epoch 10 - Validation Recall: 0.8012
# Epoch 10 - Validation Hamming Loss: 0.0697
# Exact Match Accuracy: 0.5325
# Exact genre Match Accuracy: 0.6316
# Exact mood Match Accuracy: 0.8173
# ------------------------------
# Epoch 11 - Average Training Loss: 0.0369
# Epoch 11 - Average Validation Loss: 0.2420
# Epoch 11 - Validation F1 Score: 0.8270
# Epoch 11 - Validation Precision: 0.8573
# Epoch 11 - Validation Recall: 0.7988
# Epoch 11 - Validation Hamming Loss: 0.0694
# Exact Match Accuracy: 0.5387
# Exact genre Match Accuracy: 0.6347
# Exact mood Match Accuracy: 0.8204
# ------------------------------
# Epoch 12 - Average Training Loss: 0.0347
# Epoch 12 - Average Validation Loss: 0.2483
# Epoch 12 - Validation F1 Score: 0.8227
# Epoch 12 - Validation Precision: 0.8552
# Epoch 12 - Validation Recall: 0.7925
# Epoch 12 - Validation Hamming Loss: 0.0709
# Exact Match Accuracy: 0.5387
# Exact genre Match Accuracy: 0.6378
# Exact mood Match Accuracy: 0.8111
# ------------------------------
# Epoch 13 - Average Training Loss: 0.0336
# Epoch 13 - Average Validation Loss: 0.2477
# Epoch 13 - Validation F1 Score: 0.8332
# Epoch 13 - Validation Precision: 0.8650
# Epoch 13 - Validation Recall: 0.8037
# Epoch 13 - Validation Hamming Loss: 0.0668
# Exact Match Accuracy: 0.5418
# Exact genre Match Accuracy: 0.6440
# Exact mood Match Accuracy: 0.8204
# ------------------------------
# Epoch 14 - Average Training Loss: 0.0313
# Epoch 14 - Average Validation Loss: 0.2482
# Epoch 14 - Validation F1 Score: 0.8334
# Epoch 14 - Validation Precision: 0.8640
# Epoch 14 - Validation Recall: 0.8050
# Epoch 14 - Validation Hamming Loss: 0.0668
# Exact Match Accuracy: 0.5418
# Exact genre Match Accuracy: 0.6409
# Exact mood Match Accuracy: 0.8204
# ------------------------------
# Epoch 15 - Average Training Loss: 0.0301
# Epoch 15 - Average Validation Loss: 0.2536
# Epoch 15 - Validation F1 Score: 0.8334
# Epoch 15 - Validation Precision: 0.8640
# Epoch 15 - Validation Recall: 0.8050
# Epoch 15 - Validation Hamming Loss: 0.0668
# Exact Match Accuracy: 0.5604
# Exact genre Match Accuracy: 0.6594
# Exact mood Match Accuracy: 0.8173
# ------------------------------
# Epoch 16 - Average Training Loss: 0.0281
# Epoch 16 - Average Validation Loss: 0.2576
# Epoch 16 - Validation F1 Score: 0.8315
# Epoch 16 - Validation Precision: 0.8656
# Epoch 16 - Validation Recall: 0.8000
# Epoch 16 - Validation Hamming Loss: 0.0673
# Exact Match Accuracy: 0.5604
# Exact genre Match Accuracy: 0.6563
# Exact mood Match Accuracy: 0.8173
# ------------------------------
# Epoch 17 - Average Training Loss: 0.0259
# Epoch 17 - Average Validation Loss: 0.2587
# Epoch 17 - Validation F1 Score: 0.8337
# Epoch 17 - Validation Precision: 0.8703
# Epoch 17 - Validation Recall: 0.8000
# Epoch 17 - Validation Hamming Loss: 0.0663
# Exact Match Accuracy: 0.5604
# Exact genre Match Accuracy: 0.6502
# Exact mood Match Accuracy: 0.8173
# ------------------------------
# Epoch 18 - Average Training Loss: 0.0257
# Epoch 18 - Average Validation Loss: 0.2588
# Epoch 18 - Validation F1 Score: 0.8327
# Epoch 18 - Validation Precision: 0.8638
# Epoch 18 - Validation Recall: 0.8037
# Epoch 18 - Validation Hamming Loss: 0.0671
# Exact Match Accuracy: 0.5573
# Exact genre Match Accuracy: 0.6563
# Exact mood Match Accuracy: 0.8111
# ------------------------------
# Epoch 19 - Average Training Loss: 0.0234
# Epoch 19 - Average Validation Loss: 0.2580
# Epoch 19 - Validation F1 Score: 0.8426
# Epoch 19 - Validation Precision: 0.8723
# Epoch 19 - Validation Recall: 0.8149
# Epoch 19 - Validation Hamming Loss: 0.0632
# Exact Match Accuracy: 0.5789
# Exact genre Match Accuracy: 0.6811
# Exact mood Match Accuracy: 0.8173
# ------------------------------
# Epoch 20 - Average Training Loss: 0.0231
# Epoch 20 - Average Validation Loss: 0.2637
# Epoch 20 - Validation F1 Score: 0.8343
# Epoch 20 - Validation Precision: 0.8673
# Epoch 20 - Validation Recall: 0.8037
# Epoch 20 - Validation Hamming Loss: 0.0663
# Exact Match Accuracy: 0.5635
# Exact genre Match Accuracy: 0.6533
# Exact mood Match Accuracy: 0.8204
# ------------------------------
# Epoch 21 - Average Training Loss: 0.0214
# Epoch 21 - Average Validation Loss: 0.2626
# Epoch 21 - Validation F1 Score: 0.8382
# Epoch 21 - Validation Precision: 0.8601
# Epoch 21 - Validation Recall: 0.8174
# Epoch 21 - Validation Hamming Loss: 0.0655
# Exact Match Accuracy: 0.5759
# Exact genre Match Accuracy: 0.6749
# Exact mood Match Accuracy: 0.8173
# ------------------------------
# Epoch 22 - Average Training Loss: 0.0213
# Epoch 22 - Average Validation Loss: 0.2640
# Epoch 22 - Validation F1 Score: 0.8397
# Epoch 22 - Validation Precision: 0.8717
# Epoch 22 - Validation Recall: 0.8099
# Epoch 22 - Validation Hamming Loss: 0.0642
# Exact Match Accuracy: 0.5820
# Exact genre Match Accuracy: 0.6749
# Exact mood Match Accuracy: 0.8204
# ------------------------------
# Epoch 23 - Average Training Loss: 0.0192
# Epoch 23 - Average Validation Loss: 0.2746
# Epoch 23 - Validation F1 Score: 0.8416
# Epoch 23 - Validation Precision: 0.8700
# Epoch 23 - Validation Recall: 0.8149
# Epoch 23 - Validation Hamming Loss: 0.0637
# Exact Match Accuracy: 0.5789
# Exact genre Match Accuracy: 0.6718
# Exact mood Match Accuracy: 0.8235
# ------------------------------
# Epoch 24 - Average Training Loss: 0.0188
# Epoch 24 - Average Validation Loss: 0.2722
# Epoch 24 - Validation F1 Score: 0.8462
# Epoch 24 - Validation Precision: 0.8701
# Epoch 24 - Validation Recall: 0.8236
# Epoch 24 - Validation Hamming Loss: 0.0622
# Exact Match Accuracy: 0.5944
# Exact genre Match Accuracy: 0.6935
# Exact mood Match Accuracy: 0.8266
# ------------------------------
# Epoch 25 - Average Training Loss: 0.0172
# Epoch 25 - Average Validation Loss: 0.2765
# Epoch 25 - Validation F1 Score: 0.8352
# Epoch 25 - Validation Precision: 0.8594
# Epoch 25 - Validation Recall: 0.8124
# Epoch 25 - Validation Hamming Loss: 0.0666
# Exact Match Accuracy: 0.5728
# Exact genre Match Accuracy: 0.6718
# Exact mood Match Accuracy: 0.8173
# ------------------------------
# Epoch 26 - Average Training Loss: 0.0167
# Epoch 26 - Average Validation Loss: 0.2691
# Epoch 26 - Validation F1 Score: 0.8397
# Epoch 26 - Validation Precision: 0.8675
# Epoch 26 - Validation Recall: 0.8137
# Epoch 26 - Validation Hamming Loss: 0.0645
# Exact Match Accuracy: 0.5913
# Exact genre Match Accuracy: 0.6842
# Exact mood Match Accuracy: 0.8204
# ------------------------------
# Epoch 27 - Average Training Loss: 0.0161
# Epoch 27 - Average Validation Loss: 0.2732
# Epoch 27 - Validation F1 Score: 0.8464
# Epoch 27 - Validation Precision: 0.8732
# Epoch 27 - Validation Recall: 0.8211
# Epoch 27 - Validation Hamming Loss: 0.0619
# Exact Match Accuracy: 0.6037
# Exact genre Match Accuracy: 0.6997
# Exact mood Match Accuracy: 0.8235
# ------------------------------
# Epoch 28 - Average Training Loss: 0.0155
# Epoch 28 - Average Validation Loss: 0.2766
# Epoch 28 - Validation F1 Score: 0.8440
# Epoch 28 - Validation Precision: 0.8696
# Epoch 28 - Validation Recall: 0.8199
# Epoch 28 - Validation Hamming Loss: 0.0630
# Exact Match Accuracy: 0.6037
# Exact genre Match Accuracy: 0.6966
# Exact mood Match Accuracy: 0.8235
# ------------------------------
# Epoch 29 - Average Training Loss: 0.0142
# Epoch 29 - Average Validation Loss: 0.2797
# Epoch 29 - Validation F1 Score: 0.8476
# Epoch 29 - Validation Precision: 0.8634
# Epoch 29 - Validation Recall: 0.8323
# Epoch 29 - Validation Hamming Loss: 0.0622
# Exact Match Accuracy: 0.5975
# Exact genre Match Accuracy: 0.6904
# Exact mood Match Accuracy: 0.8235
# ------------------------------
# Epoch 30 - Average Training Loss: 0.0143
# Epoch 30 - Average Validation Loss: 0.2782
# Epoch 30 - Validation F1 Score: 0.8457
# Epoch 30 - Validation Precision: 0.8649
# Epoch 30 - Validation Recall: 0.8273
# Epoch 30 - Validation Hamming Loss: 0.0627
# Exact Match Accuracy: 0.5882
# Exact genre Match Accuracy: 0.6811
# Exact mood Match Accuracy: 0.8235
# ------------------------------

# %%
# Set the model to evaluation mode
custom_head.eval()
from sklearn.metrics import f1_score, precision_score, recall_score, hamming_loss

# Initialize variables to store results
test_loss = 0
test_predictions = []
test_true_labels = []

# Loss function
loss_fn = BCEWithLogitsLoss()

# No gradient is needed for evaluation
with torch.no_grad():
    for batch in test_loader:

        text_emb = batch['text_embedding'].to(device)
        ast_emb = batch['ast_embedding'].to(device)
        labels = batch['labels'].to(device)

        outputs = custom_head(text_emb.squeeze(1), ast_emb.squeeze(1))
        loss = loss_fn(outputs, labels)
        test_loss += loss.item()

        # Store predictions and true labels
        test_predictions.append(torch.sigmoid(outputs).cpu().numpy())
        test_true_labels.append(labels.cpu().numpy())

# Calculate average loss
average_test_loss = test_loss / len(test_loader)
print(f"Average Test Loss: {average_test_loss:.4f}")

# Flatten the outputs
test_predictions = np.vstack(test_predictions)
test_true_labels = np.vstack(test_true_labels)

# Convert probabilities to binary predictions
threshold = 0.5
test_predictions[test_predictions >= threshold] = 1
test_predictions[test_predictions < threshold] = 0

# Calculate metrics
f1 = f1_score(test_true_labels, test_predictions, average='micro')
precision = precision_score(test_true_labels, test_predictions, average='micro')
recall = recall_score(test_true_labels, test_predictions, average='micro')
f1_mac = f1_score(test_true_labels, test_predictions, average='macro')
precision_mac = precision_score(test_true_labels, test_predictions, average='macro')
recall_mac = recall_score(test_true_labels, test_predictions, average='macro')
f1_w = f1_score(test_true_labels, test_predictions, average='weighted')
precision_w = precision_score(test_true_labels, test_predictions, average='weighted')
recall_w = recall_score(test_true_labels, test_predictions, average='weighted')
hamming = hamming_loss(test_true_labels, test_predictions)
ema_score, genre_score, mood_score = exact_match_accuracy(test_true_labels, test_predictions)
print(f"F1 Score: {f1:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print("-"*30)
print(f"Hamming Loss: {hamming:.4f}")
print(f"F1 Score Macro: {f1_mac:.4f}")
print(f"Precision Macro: {precision_mac:.4f}")
print(f"Recall Macro: {recall_mac:.4f}")
print("-"*30)
print(f"F1 Score W: {f1_w:.4f}")
print(f"Precision W: {precision_w:.4f}")
print(f"Recall W: {recall_w:.4f}")
print(f"Exact Match Accuracy: {ema_score:.4f}")
print(f"Exact Match Accuracy genre: {genre_score:.4f}")
print(f"Exact Match Accuracy mood: {mood_score:.4f}")
# Out:
# Average Test Loss: 0.2324
# F1 Score: 0.8558
# Precision: 0.8653
# Recall: 0.8465
# ------------------------------
# Hamming Loss: 0.0571
# F1 Score Macro: 0.8662
# Precision Macro: 0.8787
# Recall Macro: 0.8561
# ------------------------------
# F1 Score W: 0.8560
# Precision W: 0.8674
# Recall W: 0.8465
# Exact Match Accuracy: 0.6262
# Exact Match Accuracy genre: 0.7426
# Exact Match Accuracy mood: 0.8094
